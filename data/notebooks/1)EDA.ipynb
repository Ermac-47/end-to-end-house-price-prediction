# %% [markdown]
# GENERATE THE DATA SOURCE USING PANDAS

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r'C:\Users\Tauseef uddin khan\Documents\Eshaan-Personal\Projects\Personal_Projects\house_price_predictions\data\boston.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# PERFORM EDA ON THE GIVEN DATA

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.columns = [
    'crime_rate', 'residential_land_zone', 'industrial_area', 'charles_river',
    'nitric_oxide', 'avg_rooms', 'older_buildings_pct', 'distance_to_employment',
    'highway_access', 'property_tax', 'student_teacher_ratio',
    'black_index', 'lower_status_pct', 'median_value'
]

# %%
df.head()
# Out:
#    crime_rate  residential_land_zone  industrial_area  charles_river  \
# 0     0.00632                   18.0             2.31              0
# 1     0.02731                    0.0             7.07              0
# 2     0.02729                    0.0             7.07              0
# 3     0.03237                    0.0             2.18              0
# 4     0.06905                    0.0             2.18              0
#
#    nitric_oxide  avg_rooms  older_buildings_pct  distance_to_employment  \
# 0         0.538      6.575                 65.2                  4.0900
# 1         0.469      6.421                 78.9                  4.9671
# 2         0.469      7.185                 61.1                  4.9671
# 3         0.458      6.998                 45.8                  6.0622
# 4         0.458      7.147                 54.2                  6.0622
#
#    highway_access  property_tax  student_teacher_ratio  black_index  \
# ...

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   crime_rate              506 non-null    float64
#  1   residential_land_zone   506 non-null    float64
#  2   industrial_area         506 non-null    float64
#  3   charles_river           506 non-null    int64
#  4   nitric_oxide            506 non-null    float64
#  5   avg_rooms               506 non-null    float64
#  6   older_buildings_pct     506 non-null    float64
#  7   distance_to_employment  506 non-null    float64
#  8   highway_access          506 non-null    int64
#  9   property_tax            506 non-null    int64
#  10  student_teacher_ratio   506 non-null    float64
#  11  black_index             506 non-null    float64
#  12  lower_status_pct        506 non-null    float64
#  13  median_value            506 non-null    float64
# ...

# %%
df.describe()
# Out:
#        crime_rate  residential_land_zone  industrial_area  charles_river  \
# count  506.000000             506.000000       506.000000     506.000000
# mean     3.613524              11.363636        11.136779       0.069170
# std      8.601545              23.322453         6.860353       0.253994
# min      0.006320               0.000000         0.460000       0.000000
# 25%      0.082045               0.000000         5.190000       0.000000
# 50%      0.256510               0.000000         9.690000       0.000000
# 75%      3.677083              12.500000        18.100000       0.000000
# max     88.976200             100.000000        27.740000       1.000000
#
#        nitric_oxide   avg_rooms  older_buildings_pct  distance_to_employment  \
# count    506.000000  506.000000           506.000000              506.000000
# mean       0.554695    6.284634            68.574901                3.795043
# std        0.115878    0.702617            28.148861                2.105710
# ...

# %% [markdown]
# generate a univariate analysis

# %%
df.hist(figsize=(15, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# BOXPLOT FOR OUTLIERS

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.title("Boxplot of All Features")
plt.show()

# %% [markdown]
# CORRELATION MATRIX AND HEATMAP

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# TARGET VARIABLE

# %%
sns.histplot(df['median_value'], kde=True, bins=30)
plt.title("Distribution of House Prices")
plt.show()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [crime_rate, residential_land_zone, industrial_area, charles_river, nitric_oxide, avg_rooms, older_buildings_pct, distance_to_employment, highway_access, property_tax, student_teacher_ratio, black_index, lower_status_pct, median_value]
# Index: []

# %%
df.corr()
# Out:
#                         crime_rate  residential_land_zone  industrial_area  \
# crime_rate                1.000000              -0.200469         0.406583
# residential_land_zone    -0.200469               1.000000        -0.533828
# industrial_area           0.406583              -0.533828         1.000000
# charles_river            -0.055892              -0.042697         0.062938
# nitric_oxide              0.420972              -0.516604         0.763651
# avg_rooms                -0.219247               0.311991        -0.391676
# older_buildings_pct       0.352734              -0.569537         0.644779
# distance_to_employment   -0.379670               0.664408        -0.708027
# highway_access            0.625505              -0.311948         0.595129
# property_tax              0.582764              -0.314563         0.720760
# student_teacher_ratio     0.289946              -0.391679         0.383248
# ...

# %%
df.median_value.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='median_value'>

# %%
sns.histplot(df['median_value'])
# Out:
# <Axes: xlabel='median_value', ylabel='Count'>

# %%
sns.boxplot(x=df['median_value'])
# Out:
# <Axes: xlabel='median_value'>

# %%
df.dtypes
# Out:
# crime_rate                float64
# residential_land_zone     float64
# industrial_area           float64
# charles_river               int64
# nitric_oxide              float64
# avg_rooms                 float64
# older_buildings_pct       float64
# distance_to_employment    float64
# highway_access              int64
# property_tax                int64
# student_teacher_ratio     float64
# black_index               float64
# lower_status_pct          float64
# median_value              float64
# dtype: object

# %%
df.head()
# Out:
#    crime_rate  residential_land_zone  industrial_area  charles_river  \
# 0     0.00632                   18.0             2.31              0
# 1     0.02731                    0.0             7.07              0
# 2     0.02729                    0.0             7.07              0
# 3     0.03237                    0.0             2.18              0
# 4     0.06905                    0.0             2.18              0
#
#    nitric_oxide  avg_rooms  older_buildings_pct  distance_to_employment  \
# 0         0.538      6.575                 65.2                  4.0900
# 1         0.469      6.421                 78.9                  4.9671
# 2         0.469      7.185                 61.1                  4.9671
# 3         0.458      6.998                 45.8                  6.0622
# 4         0.458      7.147                 54.2                  6.0622
#
#    highway_access  property_tax  student_teacher_ratio  black_index  \
# ...
